# %%
import requests
import pandas as pd

url = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"
data = requests.get(url).json()

stations = pd.DataFrame(data["data"]["stations"])

capacities = stations[["station_id", "name", "lat", "lon", "capacity"]]
print(capacities.head())
# Out:
#                              station_id                             name  \
# 0                   1905837242740508940                 31 St & Broadway
# 1  a47f77a2-9008-4652-a4f1-b95eee723a1b               W 35 St & Dyer Ave
# 2  66dd4ccc-0aca-11e7-82f6-3863bb44ef7c         Central Park W & W 72 St
# 3  498d7e8e-5164-4f26-9ce6-399947d73b1a      Suydam St & St Nicholas Ave
# 4  66db3687-0aca-11e7-82f6-3863bb44ef7c  Columbia Heights & Cranberry St
#
#          lat        lon  capacity
# 0  40.762110 -73.925230        35
# 1  40.754692 -73.997402        41
# 2  40.775794 -73.976206        51
# 3  40.706360 -73.919450        17
# 4  40.700379 -73.995481        37
