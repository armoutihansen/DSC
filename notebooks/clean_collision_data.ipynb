# %% [markdown]
# # NYC Motor Vehicle Collisions - Crashes
#
# The purpose of this notebook is to clean and prepare the collision data, so that it eventually can be merged with CitiBike data

# %% [markdown]
# ## 1. Imports and data loading

# %%
import numpy as np
import pandas as pd
import requests
import os
from dotenv import load_dotenv
from functools import lru_cache

load_dotenv()

df = pd.read_csv("../data/Motor_Vehicle_Collisions_-_Crashes_20251117.csv",
                 low_memory=False)

# %% [markdown]
# ## 2. Overview

# %%
# Check column data types
print(df.info())
# Check for missing values in each column
print(df.isnull().mean())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2220334 entries, 0 to 2220333
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
#  17  NUMBER OF MOTORIST KILLED      int64
#  18  CONTRIBUTING FACTOR VEHICLE 1  object
#  19  CONTRIBUTING FACTOR VEHICLE 2  object
#  20  CONTRIBUTING FACTOR VEHICLE 3  object
#  21  CONTRIBUTING FACTOR VEHICLE 4  object
#  22  CONTRIBUTING FACTOR VEHICLE 5  object
#  23  COLLISION_ID                   int64
#  24  VEHICLE TYPE CODE 1            object
#  25  VEHICLE TYPE CODE 2            object
#  26  VEHICLE TYPE CODE 3            object
#  27  VEHICLE TYPE CODE 4            object
#  28  VEHICLE TYPE CODE 5            object
# dtypes: float64(4), int64(7), object(18)
# memory usage: 491.3+ MB
# None
# CRASH DATE                       0.000000
# CRASH TIME                       0.000000
# BOROUGH                          0.306384
# ZIP CODE                         0.306508
# LATITUDE                         0.108254
# LONGITUDE                        0.108254
# LOCATION                         0.108254
# ON STREET NAME                   0.217811
# CROSS STREET NAME                0.382118
# OFF STREET NAME                  0.823792
# NUMBER OF PERSONS INJURED        0.000008
# NUMBER OF PERSONS KILLED         0.000014
# NUMBER OF PEDESTRIANS INJURED    0.000000
# NUMBER OF PEDESTRIANS KILLED     0.000000
# NUMBER OF CYCLIST INJURED        0.000000
# NUMBER OF CYCLIST KILLED         0.000000
# NUMBER OF MOTORIST INJURED       0.000000
# NUMBER OF MOTORIST KILLED        0.000000
# CONTRIBUTING FACTOR VEHICLE 1    0.003531
# CONTRIBUTING FACTOR VEHICLE 2    0.160535
# CONTRIBUTING FACTOR VEHICLE 3    0.927642
# CONTRIBUTING FACTOR VEHICLE 4    0.983480
# CONTRIBUTING FACTOR VEHICLE 5    0.995475
# COLLISION_ID                     0.000000
# VEHICLE TYPE CODE 1              0.007275
# VEHICLE TYPE CODE 2              0.200603
# VEHICLE TYPE CODE 3              0.930451
# VEHICLE TYPE CODE 4              0.984080
# VEHICLE TYPE CODE 5              0.995618
# dtype: float64

# %%
# Check first few rows
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN    11230  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                      LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                         NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                         NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2      (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# 3                         NaN       THROGS NECK BRIDGE               NaN
# 4                         NaN          BROOKLYN BRIDGE               NaN
#
#   OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN  ...                    Unspecified
# 1             NaN  ...                            NaN
# 2             NaN  ...                    Unspecified
# 3             NaN  ...                    Unspecified
# 4             NaN  ...                    Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                    Unspecified                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4455765
# 1                            NaN       4513547
# 2                            NaN       4675373
# 3                            NaN       4541903
# 4                            NaN       4566131
#
#                    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# 0                                Sedan                Sedan
# 1                                Sedan                  NaN
# 2                                Moped                Sedan
# 3                                Sedan        Pick-up Truck
# 4  Station Wagon/Sport Utility Vehicle                  NaN
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                Sedan                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
# Combine date and time columns into a single datetime column
df["CRASH DATETIME"] = pd.to_datetime(df["CRASH DATE"] + " " + df["CRASH TIME"])

# Inline with our citibike, we focus on data from 2023-01-01 to 2025-10-31
df = df[(df["CRASH DATETIME"] >= "2023-01-01") & (df["CRASH DATETIME"] <= "2025-10-31")]

# %% [markdown]
# ## Subsetting the data to accidents involving cyclists
#
# We have direct information on (i) whether a cyclist was killed, and (ii) whether a cyclist was injured. However, we also care about accidents involving cyclist in which they were neither killed nor injured. For this, we need to investigate VEHICLE TYPE CODE 1 - 5.

# %%
# List of vehicle type columns
veh_cols = [f"VEHICLE TYPE CODE {i}" for i in range(1, 6)]

# Start with a mask of all False
cyclist_mask = pd.Series(False, index=df.index)

for col in veh_cols:
    s = df[col].astype("string").str.lower()

    is_bike = s.str.contains("bik", na=False) & \
              ~s.str.contains("motor|dirt", na=False)

    is_cycle = s.str.contains("cyc", na=False) & \
               ~s.str.contains("motor|quad", na=False)

    cyclist_mask |= (is_bike | is_cycle)

# Final indicator column: 1 if any of the 5 vehicle codes matches, else 0
df["CYCLIST_INVOLVED"] = cyclist_mask.astype(int)

df["CYCLIST_INVOLVED"] = (
    (df["CYCLIST_INVOLVED"] == 1) |
    (df["NUMBER OF CYCLIST INJURED"] > 0) |
    (df["NUMBER OF CYCLIST KILLED"] > 0)
).astype(int)

# %%
df.loc[df["CYCLIST_INVOLVED"] == 1, veh_cols].head()
df_sub = df

# %% [markdown]
# ## Dealing with remaining missing locations
# For our analysis, it is necessary that we know the location of the cyclist-involved accident.

# %%
# Check the number of instances ZIP CODE is not missing, but LATITUDE or LONGITUDE is missing
df_sub[((df_sub["LATITUDE"].isna()) | (df_sub["LONGITUDE"].isna())) & (df_sub["ZIP CODE"].notna())].shape
# Out:
# (2226, 31)

# %%
# Check the number of instances BOROUGH is not missing, but LATITUDE or LONGITUDE and ZIP CODE are missing
df_sub[((df_sub["LATITUDE"].isna()) | (df_sub["LONGITUDE"].isna())) & (df_sub["ZIP CODE"].isna()) & (df_sub["BOROUGH"].notna())].shape
# Out:
# (3, 31)

# %% [markdown]
# As ZIP CODE is preferred to BOROUGH, the approach we use is as follows:
# 1. Fill missing LATITUDE and LONGITUDE using NYC GEOCLIENT (v2)
# 2. Use ZIP CODE medians
# 3. Drop remaining, as we cannot reasonably assign location

# %%
GEOCLIENT_KEY = os.getenv("GEOCLIENT_KEY")
URL = "https://api.nyc.gov/geoclient/v2/search"

@lru_cache(maxsize=50_000)
def geocode(query: str):

    query_norm = query.strip().lower()

    headers = {
        "Ocp-Apim-Subscription-Key": GEOCLIENT_KEY
    }
    params = {"input": query_norm}

    r = requests.get(URL, headers=headers, params=params, timeout=8)
    if r.status_code != 200:
        return None, None

    data = r.json()
    results = data.get("results") or []
    if not results:
        return None, None

    resp = results[0].get("response", {})
    lat = resp.get("latitude")
    lon = resp.get("longitude")

    if lat is None or lon is None:
        return None, None
    return float(lat), float(lon)

def build_query(row):
    on = str(row.get("ON STREET NAME", "") or "").strip()
    cross = str(row.get("CROSS STREET NAME") or "").strip()
    bor = str(row.get("BOROUGH") or "").strip()
    
    if on and cross and bor:
        return f"{on} & {cross}, {bor}, NY"
    if on and bor:
        return f"{on}, {bor}, NY"

    return None

# %%
mask = df_sub["LATITUDE"].isna() | df_sub["LONGITUDE"].isna()
c = 0
for idx, row in df_sub[mask].iterrows():
    c += 1
    if c % 100 == 0:
        print(f"Geocoding record {c} of {len(df_sub[mask])}")
    q = build_query(row)
    lat, lon = geocode(q)
    df_sub.at[idx, "LATITUDE"] = lat
    df_sub.at[idx, "LONGITUDE"] = lon
# Out:
# Geocoding record 100 of 15164
# Geocoding record 200 of 15164
# Geocoding record 300 of 15164
# Geocoding record 400 of 15164
# Geocoding record 500 of 15164
# Geocoding record 600 of 15164
# Geocoding record 700 of 15164
# Geocoding record 800 of 15164
# Geocoding record 900 of 15164
# Geocoding record 1000 of 15164
# Geocoding record 1100 of 15164
# Geocoding record 1200 of 15164
# Geocoding record 1300 of 15164
# Geocoding record 1400 of 15164
# Geocoding record 1500 of 15164
# Geocoding record 1600 of 15164
# Geocoding record 1700 of 15164
# Geocoding record 1800 of 15164
# Geocoding record 1900 of 15164
# Geocoding record 2000 of 15164
# Geocoding record 2100 of 15164
# Geocoding record 2200 of 15164
# Geocoding record 2300 of 15164
# Geocoding record 2400 of 15164
# Geocoding record 2500 of 15164
# Geocoding record 2600 of 15164
# Geocoding record 2700 of 15164
# Geocoding record 2800 of 15164
# Geocoding record 2900 of 15164
# Geocoding record 3000 of 15164
# Geocoding record 3100 of 15164
# Geocoding record 3200 of 15164
# Geocoding record 3300 of 15164
# Geocoding record 3400 of 15164
# Geocoding record 3500 of 15164
# Geocoding record 3600 of 15164
# Geocoding record 3700 of 15164
# Geocoding record 3800 of 15164
# Geocoding record 3900 of 15164
# Geocoding record 4000 of 15164
# Geocoding record 4100 of 15164
# Geocoding record 4200 of 15164
# Geocoding record 4300 of 15164
# Geocoding record 4400 of 15164
# Geocoding record 4500 of 15164
# Geocoding record 4600 of 15164
# Geocoding record 4700 of 15164
# Geocoding record 4800 of 15164
# Geocoding record 4900 of 15164
# Geocoding record 5000 of 15164
# Geocoding record 5100 of 15164
# Geocoding record 5200 of 15164
# Geocoding record 5300 of 15164
# Geocoding record 5400 of 15164
# Geocoding record 5500 of 15164
# Geocoding record 5600 of 15164
# Geocoding record 5700 of 15164
# Geocoding record 5800 of 15164
# Geocoding record 5900 of 15164
# Geocoding record 6000 of 15164
# Geocoding record 6100 of 15164
# Geocoding record 6200 of 15164
# Geocoding record 6300 of 15164
# Geocoding record 6400 of 15164
# Geocoding record 6500 of 15164
# Geocoding record 6600 of 15164
# Geocoding record 6700 of 15164
# Geocoding record 6800 of 15164
# Geocoding record 6900 of 15164
# Geocoding record 7000 of 15164
# Geocoding record 7100 of 15164
# Geocoding record 7200 of 15164
# Geocoding record 7300 of 15164
# Geocoding record 7400 of 15164
# Geocoding record 7500 of 15164
# Geocoding record 7600 of 15164
# Geocoding record 7700 of 15164
# Geocoding record 7800 of 15164
# Geocoding record 7900 of 15164
# Geocoding record 8000 of 15164
# Geocoding record 8100 of 15164
# Geocoding record 8200 of 15164
# Geocoding record 8300 of 15164
# Geocoding record 8400 of 15164
# Geocoding record 8500 of 15164
# Geocoding record 8600 of 15164
# Geocoding record 8700 of 15164
# Geocoding record 8800 of 15164
# Geocoding record 8900 of 15164
# Geocoding record 9000 of 15164
# Geocoding record 9100 of 15164
# Geocoding record 9200 of 15164
# Geocoding record 9300 of 15164
# Geocoding record 9400 of 15164
# Geocoding record 9500 of 15164
# Geocoding record 9600 of 15164
# Geocoding record 9700 of 15164
# Geocoding record 9800 of 15164
# Geocoding record 9900 of 15164
# Geocoding record 10000 of 15164
# Geocoding record 10100 of 15164
# Geocoding record 10200 of 15164
# Geocoding record 10300 of 15164
# Geocoding record 10400 of 15164
# Geocoding record 10500 of 15164
# Geocoding record 10600 of 15164
# Geocoding record 10700 of 15164
# Geocoding record 10800 of 15164
# Geocoding record 10900 of 15164
# Geocoding record 11000 of 15164
# Geocoding record 11100 of 15164
# Geocoding record 11200 of 15164
# Geocoding record 11300 of 15164
# Geocoding record 11400 of 15164
# Geocoding record 11500 of 15164
# Geocoding record 11600 of 15164
# Geocoding record 11700 of 15164
# Geocoding record 11800 of 15164
# Geocoding record 11900 of 15164
# Geocoding record 12000 of 15164
# Geocoding record 12100 of 15164
# Geocoding record 12200 of 15164
# Geocoding record 12300 of 15164
# Geocoding record 12400 of 15164
# Geocoding record 12500 of 15164
# Geocoding record 12600 of 15164
# Geocoding record 12700 of 15164
# Geocoding record 12800 of 15164
# Geocoding record 12900 of 15164
# Geocoding record 13000 of 15164
# Geocoding record 13100 of 15164
# Geocoding record 13200 of 15164
# Geocoding record 13300 of 15164
# Geocoding record 13400 of 15164
# Geocoding record 13500 of 15164
# Geocoding record 13600 of 15164
# Geocoding record 13700 of 15164
# Geocoding record 13800 of 15164
# Geocoding record 13900 of 15164
# Geocoding record 14000 of 15164
# Geocoding record 14100 of 15164
# Geocoding record 14200 of 15164
# Geocoding record 14300 of 15164
# Geocoding record 14400 of 15164
# Geocoding record 14500 of 15164
# Geocoding record 14600 of 15164
# Geocoding record 14700 of 15164
# Geocoding record 14800 of 15164
# Geocoding record 14900 of 15164
# Geocoding record 15000 of 15164
# Geocoding record 15100 of 15164

# %%
# For the remaining missing lat/lon, we first use ZIP CODE medians
zip_medians = df_sub.groupby("ZIP CODE")[["LATITUDE", "LONGITUDE"]].median()

mask = df_sub["LATITUDE"].isna() | df_sub["LONGITUDE"].isna()
for idx, row in df_sub[mask].iterrows():
    zip_code = row["ZIP CODE"]
    if pd.notna(zip_code) and zip_code in zip_medians.index:
        df_sub.at[idx, "LATITUDE"] = zip_medians.at[zip_code, "LATITUDE"]
        df_sub.at[idx, "LONGITUDE"] = zip_medians.at[zip_code, "LONGITUDE"]

# %%
df_sub.isnull().sum()
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                           71059
# ZIP CODE                          71097
# LATITUDE                          12869
# LONGITUDE                         12869
# LOCATION                          15164
# ON STREET NAME                    74384
# CROSS STREET NAME                122663
# OFF STREET NAME                  184125
# NUMBER OF PERSONS INJURED             0
# NUMBER OF PERSONS KILLED              0
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      1828
# CONTRIBUTING FACTOR VEHICLE 2     61179
# CONTRIBUTING FACTOR VEHICLE 3    235617
# CONTRIBUTING FACTOR VEHICLE 4    252497
# CONTRIBUTING FACTOR VEHICLE 5    256689
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1                4323
# VEHICLE TYPE CODE 2               86966
# VEHICLE TYPE CODE 3              237243
# VEHICLE TYPE CODE 4              252833
# VEHICLE TYPE CODE 5              256767
# CRASH DATETIME                        0
# CYCLIST_INVOLVED                      0
# dtype: int64

# %%
# Remove missing lat/lon records
df_sub = df_sub[df_sub["LATITUDE"].notna() & df_sub["LONGITUDE"].notna()]
df_sub.isnull().sum()
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                           58193
# ZIP CODE                          58228
# LATITUDE                              0
# LONGITUDE                             0
# LOCATION                           2295
# ON STREET NAME                    73779
# CROSS STREET NAME                114573
# OFF STREET NAME                  171859
# NUMBER OF PERSONS INJURED             0
# NUMBER OF PERSONS KILLED              0
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1      1785
# CONTRIBUTING FACTOR VEHICLE 2     58529
# CONTRIBUTING FACTOR VEHICLE 3    224158
# CONTRIBUTING FACTOR VEHICLE 4    239981
# CONTRIBUTING FACTOR VEHICLE 5    243919
# COLLISION_ID                          0
# VEHICLE TYPE CODE 1                4209
# VEHICLE TYPE CODE 2               83302
# VEHICLE TYPE CODE 3              225693
# VEHICLE TYPE CODE 4              240291
# VEHICLE TYPE CODE 5              243989
# CRASH DATETIME                        0
# CYCLIST_INVOLVED                      0
# dtype: int64

# %% [markdown]
# ## Subsetting for columns we need

# %%
cols = ["CRASH DATETIME", "LATITUDE", "LONGITUDE", "CYCLIST_INVOLVED",
        "NUMBER OF PERSONS INJURED", "NUMBER OF PERSONS KILLED"]
df_sub = df_sub[cols]
df_sub.isna().sum()
# Out:
# CRASH DATETIME               0
# LATITUDE                     0
# LONGITUDE                    0
# CYCLIST_INVOLVED             0
# NUMBER OF PERSONS INJURED    0
# NUMBER OF PERSONS KILLED     0
# dtype: int64

# %%
df_sub.to_csv("../data/processed/cleaned_collision_data.csv", index=False)
